# %% [markdown]
# Inheritance is fundamental concept in OOP that allows class to inherit attributes and methods from another class
# Single and multiple ingeritance

# %%
#Inheritance
#Parent class

class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1 = Car(4, 4, "pertol")

# %%
car1.drive()
# Out:
# The person will drive the pertol car

# %%
#define child class and inherit from parent class (here Car is parent class)
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)  #call parent class constructor using super()
        self.is_selfdriving = is_selfdriving

        
    def self_driving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving}")

# %%
tesla1 = Tesla(4, 4, "electric", True)

# %%
tesla1.drive()
# Out:
# The person will drive the electric car

# %%
tesla1.self_driving()
# Out:
# Tesla supports self driving : True

# %%
#Multiple Inheritance
#when a class inherits from more than one class
#Base class 1
class Animal:
    def __init__(self, name):
        self.name = name
      
    def speak(self):
        print("Subclass must implement abstract method")


#Base class 2
class Pet:
    def __init__(self, owner):
        self.owner = owner

    def play(self):
        print(f"{self.name} is playing with {self.owner}")



#Derived class inheriting from both Animal and Pet
class Dog(Animal, Pet):
    def __init__(self, name, owner, breed):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)
        self.breed = breed

    def speaking(self):
        print(f"{self.name} says Woof!")

# %%
dog1 = Dog("Buddy", "Alice", "Golden Retriever")

# %%
dog1.speak()
dog1.play()
dog1.speaking()
# Out:
# Subclass must implement abstract method
# Buddy is playing with Alice
# Buddy says Woof!
