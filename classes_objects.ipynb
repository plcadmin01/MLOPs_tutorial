# %%
#A class is a blueprint of an object. It has its attributes and methods.

# %%
class Car:
    pass

# %%
audi = Car()
bmw = Car()

# %%
print(audi)

# %%
print(audi)
print(bmw)

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
audi.color = "red"

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'color']

# %%
class Dog:
    #constructor ( __init__ method ) where initially i can define all the attributes for this class\
    # self keyword is used to represent the instance of the class
    #init function /construtor to define instance variables which deine the properties of the object
    def __init__(self, name, age):
        self.name = name
        self.age = age


#create object
dog1 = Dog()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       7         self.age = age
#      10 #create object
# ---> 11 dog1 = Dog()
#
# TypeError: Dog.__init__() missing 2 required positional arguments: 'name' and 'age'

# %%
#create object

dog1 = Dog("Buddy", 3)

# %%
dog1.name
# Out:
# 'Buddy'

# %%
dog1.age
# Out:
# 3

# %%
dog2 = Dog("Max", 5)

# %%
dog2.age
# Out:
# 5

# %%
class Dog:
    def __init__(self,name, age):
        self.name = name
        self.age = age


    #create instance method
    def bark(self):

        print(self.name + " says woof!")

# %%
dog1 = Dog("Buddy", 3)

# %%
dog1.bark()
# Out:
# Buddy says woof!

# %%
dog2 = Dog("Max", 5)

# %%
dog2.bark()
# Out:
# Max says woof!

# %%
#Modelling a bank account 
## Define a class for Bank Account

class BankAccount:
    def __init__(self, owner,balance=0):
        self.owner = owner
        self.balance = balance

    def deposit( self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance is {self.balance}")


    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds!")

        else:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance is {self.balance}")


    def get_balance(self):
        return self.balance

# %%
account = BankAccount("Alice", 1000)

# %%
account.balance
# Out:
# 1000

# %%
account.deposit(500)
# Out:
# Deposited 500. New balance is 1500

# %%
account.withdraw(200)
# Out:
# Withdrew 200. New balance is 1300

# %%
account.get_balance()
# Out:
# 1300

# %%
account.deposit(1)
# Out:
# Deposited 1. New balance is 1301

# %%
#classes are important
#model real world scenarios
